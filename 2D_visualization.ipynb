# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("simulation_test.csv", index_col=0)

# %%
df.head()
# Out:
#             x-position  y-position  time
# Particles
# Particles0    9.743578   -7.871378     0
# Particles1    4.977432   -1.225433     0
# Particles2   -1.503461    8.061107     0
# Particles3   -2.272964    7.132600     0
# Particles4   -4.822357   -4.730748     0

# %%
sns.scatterplot(data = df ,x = 'x-position', y = 'y-position', hue = "time", s = 10.0)
#plt.xlim(-10,10)
#plt.ylim(-10,10)
# Out:
# <Axes: xlabel='x-position', ylabel='y-position'>
