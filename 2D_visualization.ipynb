# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("simulation_test.csv", index_col=0)

# %%
df.head()
# Out:
#             x-position  y-position  time
# Particles
# Particles0    7.493518   -6.279327     0
# Particles1   -0.434256    6.641008     0
# Particles2    9.215248    3.133616     0
# Particles3   -1.692582    3.742097     0
# Particles4    8.150961    6.557402     0

# %%
sns.scatterplot(data = df ,x = 'x-position', y = 'y-position', hue = "time", s = 10.0)
plt.vlines(x = 10, ymin = -10.0, ymax = 10.0)
plt.vlines(x = -10, ymin = -10.0, ymax = 10.0)
plt.hlines(y = 10, xmin = -10.0, xmax = 10.0)
plt.hlines(y = -10, xmin = -10.0, xmax = 10.0)
#plt.xlim(-10,10)
#plt.ylim(-10,10)
