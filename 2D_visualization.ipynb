# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("simulation_test.csv", index_col=0)

# %%
df.head()
# Out:
#             x-position  y-position  time
# Particles
# Particles0   -4.479631    7.208221     0
# Particles1    0.976338    8.098171     0
# Particles2   -5.555999   -5.204558     0
# Particles3    6.091609    5.183064     0
# Particles4    0.223818    9.900375     0

# %%
sns.scatterplot(data = df ,x = 'x-position', y = 'y-position', hue = "time", s = 10.0)
#plt.xlim(-10,10)
#plt.ylim(-10,10)
