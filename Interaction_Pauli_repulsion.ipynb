# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
epsilon = 0.01
prefactor_interaction = epsilon * 48.0
R = np.arange(0.5,2.0,0.001)

# %%
a = prefactor_interaction / R**14

# %%
plt.plot(R,a)

# %%
R2 = R = np.arange(1.0,2.0,0.001)
a2 = prefactor_interaction / R2**14
plt.plot(R2,a2)
