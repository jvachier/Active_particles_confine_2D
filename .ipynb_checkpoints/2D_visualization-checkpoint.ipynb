# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("simulation_test.csv", index_col=0)

# %%
df.head()
# Out:
#             x-position  y-position  time
# Particles
# Particles0   -8.853115    1.691028     0
# Particles1   -0.595682   -2.277832     0
# Particles2   -4.807938    2.601889     0
# Particles3    3.358898   -7.047547     0
# Particles4   -7.425535    6.926899     0

# %%
sns.scatterplot(data = df ,x = 'x-position', y = 'y-position', hue = "time", s = 10.0)
plt.vlines(x = 10, ymin = -10.0, ymax = 10.0)
plt.vlines(x = -10, ymin = -10.0, ymax = 10.0)
plt.hlines(y = 10, xmin = -10.0, xmax = 10.0)
plt.hlines(y = -10, xmin = -10.0, xmax = 10.0)
#plt.xlim(-10,10)
#plt.ylim(-10,10)
